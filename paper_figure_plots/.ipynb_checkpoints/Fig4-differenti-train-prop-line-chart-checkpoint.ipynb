# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # WGS Group 1

# %%
x = [0,1,2,3,4,5,6]

# LR
y0 = [0.546,0.56,0.557,0.55,0.58,0.57,0.593]
y0err = [0.042,0.072,0.065,0.052,0.035,0.063,0.04]

# RF
y1 = [0.5217, 0.54, 0.547, 0.54, 0.523, 0.523, 0.54]
y1err = [0.064755412, 0.045825757, 0.073711148, 0.079372539, 0.005773503, 0.047258156, 0.052915026]

# SVM
y2 = [0.4752, 0.5, 0.52, 0.52, 0.513333333, 0.56, 0.573333333]
y2err = [0.0277, 0.065574385, 0.055677644, 0.06244998, 0.072341781, 0.045825757, 0.049328829]

# Ours
y4 = [0.573933333, 0.603633333, 0.592766667, 0.592533333, 0.6136, 0.6218, 0.658966667]
y4err = [0.012461675, 0.028080123, 0.019696785, 0.022753974, 0.02646356, 0.03570056, 0.044675534]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot0
ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
ax.fill_between(x, y0 - np.array(y0err), y0 + np.array(y0err), alpha=0.2, facecolor='#DF9E9B',
                linewidth=0.1, antialiased=True)

# Plot1
ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
ax.fill_between(x, y1 - np.array(y1err), y1 + np.array(y1err), alpha=0.2, facecolor='#A8D3E3',
                linewidth=0.1, antialiased=True)

# Plot2
ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
ax.fill_between(x, y2 - np.array(y2err), y2 + np.array(y2err), alpha=0.2, facecolor='#ADD599',
                linewidth=0.1, antialiased=True)

# # Plot3
# ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
# ax.fill_between(x, y3 - np.array(y3err), y3 + np.array(y3err), alpha=0.2, facecolor='#F6B37F',
#                 linewidth=0.1, antialiased=True)

# Plot4
ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
ax.fill_between(x, y4 - np.array(y4err), y4 + np.array(y4err), alpha=0.4, facecolor='#AB88BE',
                linewidth=0.1, antialiased=True)

ax.set_xticklabels(['', '10%', '20%', '30%', '40%', '50%', '60%', '70%'], rotation=0, fontsize=15)
ax.set_ylabel('AUC', fontsize=18)
plt.yticks(fontsize=15)

plt.legend(fontsize=15)

plt.show()
# Out:
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/3477478018.py:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/3477478018.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/3477478018.py:33: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/3477478018.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/3477478018.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['', '10%', '20%', '30%', '40%', '50%', '60%', '70%'], rotation=0, fontsize=15)

# %% [markdown]
# # WGS Group 2

# %%
x = [0,1,2,3,4,5,6]

# LR
y0 = [0.5069, 0.5379, 0.5600, 0.5772, 0.5939, 0.5719, 0.5878]
y0err = [0.02, 0.06, 0.012, 0.027, 0.02, 0.045, 0.049]

# RF
y1 = [0.5039, 0.5179, 0.5302, 0.5210, 0.5211, 0.5036, 0.4932]
y1err = [0.03, 0.04, 0.01, 0.06, 0.05, 0.06, 0.04]

# SVM
y2 = [0.4803, 0.5216, 0.5008, 0.5324, 0.5367, 0.5426, 0.5932]
y2err = [0.007, 0.051, 0.055, 0.05, 0.047, 0.03, 0.014]

# Ours
y4 = [0.5491, 0.57, 0.5874, 0.5844, 0.5925, 0.5818, 0.6147]
y4err = [0.064, 0.078, 0.062, 0.061, 0.057, 0.07, 0.022]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot0
ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
ax.fill_between(x, y0 - np.array(y0err), y0 + np.array(y0err), alpha=0.2, facecolor='#DF9E9B',
                linewidth=0.1, antialiased=True)

# Plot1
ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
ax.fill_between(x, y1 - np.array(y1err), y1 + np.array(y1err), alpha=0.2, facecolor='#A8D3E3',
                linewidth=0.1, antialiased=True)

# Plot2
ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
ax.fill_between(x, y2 - np.array(y2err), y2 + np.array(y2err), alpha=0.2, facecolor='#ADD599',
                linewidth=0.1, antialiased=True)

# # Plot3
# ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
# ax.fill_between(x, y3 - np.array(y3err), y3 + np.array(y3err), alpha=0.2, facecolor='#F6B37F',
#                 linewidth=0.1, antialiased=True)

# Plot4
ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
ax.fill_between(x, y4 - np.array(y4err), y4 + np.array(y4err), alpha=0.4, facecolor='#AB88BE',
                linewidth=0.1, antialiased=True)

ax.set_xticklabels(['', '10%', '20%', '30%', '40%', '50%', '60%', '70%'], rotation=0, fontsize=15)
ax.set_ylabel('AUC', fontsize=18)
plt.yticks(fontsize=15)

plt.legend(fontsize=15)

plt.show()
# Out:
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/338491455.py:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/338491455.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/338491455.py:33: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/338491455.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/338491455.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['', '10%', '20%', '30%', '40%', '50%', '60%', '70%'], rotation=0, fontsize=15)

# %% [markdown]
# # WGS Group 3

# %%
x = [0,1,2,3,4,5,6]

# LR
y0 = [0.444, 0.3866, 0.413, 0.3827, 0.4175, 0.4349, 0.4607]
y0err = [0.042, 0.001, 0.07, 0.010, 0.021, 0.026, 0.0123]

# RF
y1 = [0.4235, 0.4334, 0.4096, 0.4159, 0.4057, 0.435, 0.3979]
y1err = [0.007, 0.029, 0.075, 0.045, 0.06, 0.02, 0.0173]

# SVM
y2 = [0.4993, 0.5951, 0.5645, 0.5204, 0.4014, 0.4875, 0.4175]
y2err = [0.0624, 0.0354, 0.106, 0.153, 0.0433, 0.148, 0.022]

# Ours
y4 = [0.57, 0.5697, 0.5674, 0.5826, 0.5832, 0.6074, 0.6084]
y4err = [0.037, 0.0356, 0.029, 0.026, 0.039, 0.019, 0.005]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot0
ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
ax.fill_between(x, y0 - np.array(y0err), y0 + np.array(y0err), alpha=0.2, facecolor='#DF9E9B',
                linewidth=0.1, antialiased=True)

# Plot1
ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
ax.fill_between(x, y1 - np.array(y1err), y1 + np.array(y1err), alpha=0.2, facecolor='#A8D3E3',
                linewidth=0.1, antialiased=True)

# Plot2
ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
ax.fill_between(x, y2 - np.array(y2err), y2 + np.array(y2err), alpha=0.2, facecolor='#ADD599',
                linewidth=0.1, antialiased=True)

# # Plot3
# ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
# ax.fill_between(x, y3 - np.array(y3err), y3 + np.array(y3err), alpha=0.2, facecolor='#F6B37F',
#                 linewidth=0.1, antialiased=True)

# Plot4
ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
ax.fill_between(x, y4 - np.array(y4err), y4 + np.array(y4err), alpha=0.4, facecolor='#AB88BE',
                linewidth=0.1, antialiased=True)

ax.set_xticklabels(['', '10%', '20%', '30%', '40%', '50%', '60%', '70%'], rotation=0, fontsize=15)
ax.set_ylabel('AUC', fontsize=18)
plt.yticks(fontsize=15)

plt.legend(fontsize=15)

plt.show()
# Out:
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/311808893.py:23: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/311808893.py:28: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/311808893.py:33: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/311808893.py:43: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
# /var/folders/f9/gf3wvcxj5m9bss9z30g7qqfr0000gn/T/ipykernel_54768/311808893.py:47: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(['', '10%', '20%', '30%', '40%', '50%', '60%', '70%'], rotation=0, fontsize=15)
