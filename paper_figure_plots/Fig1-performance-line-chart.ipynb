# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [0,1,2,3,4,5,6,7]

# LR
y0 = [0.566, 0.697, 0.906, 0.914, 0.8, 0.848, 0.582, 0.624]
y0err = [0.05, 0.01, 0.007, 0.007, 0.04, 0.017, 0.017, 0.008]

# RF
y1 = [0.532, 0.653, 0.913, 0.919, 0.777, 0.786, 0.673, 0.689]
y1err = [0.04, 0.01, 0.005, 0.004, 0.032, 0.012, 0.031, 0.019]

# SVM
y2 = [0.55, 0.598, 0.913, 0.918, 0.74, 0.608, 0.646, 0.664]
y2err = [0.05, 0.02, 0.005, 0.004, 0.023, 0.035, 0.029, 0.016]

# SNN
y3 = [0.5138, 0.522, 0.79, 0.807, 0.545, 0.546, 0.531, 0.541]
y3err = [0.06, 0.02, 0.013, 0.013, 0.028, 0.044, 0.042, 0.018]

# Ours
y4 = [0.6484, 0.6985, 0.921, 0.923, 0.821, 0.857, 0.668, 0.694]
y4err = [0.02, 0.02, 0.006, 0.004, 0.028, 0.023, 0.013, 0.017]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot0
ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
ax.fill_between(x, y0 - np.array(y0err), y0 + np.array(y0err), alpha=0.2, facecolor='#DF9E9B',
                linewidth=0.1, antialiased=True)

# Plot1
ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
ax.fill_between(x, y1 - np.array(y1err), y1 + np.array(y1err), alpha=0.2, facecolor='#A8D3E3',
                linewidth=0.1, antialiased=True)

# Plot2
ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
ax.fill_between(x, y2 - np.array(y2err), y2 + np.array(y2err), alpha=0.2, facecolor='#ADD599',
                linewidth=0.1, antialiased=True)

# Plot3
ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
ax.fill_between(x, y3 - np.array(y3err), y3 + np.array(y3err), alpha=0.2, facecolor='#F6B37F',
                linewidth=0.1, antialiased=True)

# Plot4
ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
ax.fill_between(x, y4 - np.array(y4err), y4 + np.array(y4err), alpha=0.4, facecolor='#AB88BE',
                linewidth=0.1, antialiased=True)

ax.set_xticklabels(['', 'WGS', 'Framingham', 'Heart (S)', 'Heart (F)', 'Stroke (S)', 'Stroke (F)', 'Breast (S)', 'Breast (F)'], rotation=40, fontsize=15)
ax.set_ylabel('AUC', fontsize=18)
plt.yticks(fontsize=15)

plt.legend(fontsize=15)

plt.show()
# Out:
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/4270308892.py:27: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/4270308892.py:32: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/4270308892.py:37: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/4270308892.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/4270308892.py:47: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/4270308892.py:51: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(['', 'WGS', 'Framingham', 'Heart (S)', 'Heart (F)', 'Stroke (S)', 'Stroke (F)', 'Breast (S)', 'Breast (F)'], rotation=40, fontsize=15)

# %% [markdown]
# # new version with separate plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Data
x = [0, 1, 2, 3, 4]
labels = ['Framingham (S)', 'MIMIC (S)', 'Heart (S)', 'Stroke (S)', 'Breast (S)']

# LR
y0 = [0.70, 0.611, 0.906, 0.8, 0.582]
y0err = [0.013, 0.012, 0.007, 0.04, 0.017]

# RF
y1 = [0.668, 0.83, 0.913, 0.777, 0.673]
y1err = [0.001, 0.016, 0.005, 0.032, 0.031]

# SVM
y2 = [0.598, 0.507, 0.913, 0.74, 0.646]
y2err = [0.028, 0.009, 0.005, 0.023, 0.029]

# SNN
y3 = [0.542, 0.822, 0.79, 0.545, 0.531]
y3err = [0.012, 0.001, 0.013, 0.028, 0.042]

# Ours
y4 = [0.706, 0.951, 0.921, 0.821, 0.668]
y4err = [0.006, 0.012, 0.006, 0.028, 0.013]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot0
ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
ax.fill_between(x, y0 - np.array(y0err), y0 + np.array(y0err), alpha=0.2, facecolor='#DF9E9B',
                linewidth=0.1, antialiased=True)

# Plot1
ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
ax.fill_between(x, y1 - np.array(y1err), y1 + np.array(y1err), alpha=0.2, facecolor='#A8D3E3',
                linewidth=0.1, antialiased=True)

# Plot2
ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
ax.fill_between(x, y2 - np.array(y2err), y2 + np.array(y2err), alpha=0.2, facecolor='#ADD599',
                linewidth=0.1, antialiased=True)

# Plot3
ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
ax.fill_between(x, y3 - np.array(y3err), y3 + np.array(y3err), alpha=0.2, facecolor='#F6B37F',
                linewidth=0.1, antialiased=True)

# Plot4
ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
ax.fill_between(x, y4 - np.array(y4err), y4 + np.array(y4err), alpha=0.4, facecolor='#AB88BE',
                linewidth=0.1, antialiased=True)

# Set x-axis ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=30, fontsize=15)
ax.set_ylabel('AUC', fontsize=18)
plt.yticks(fontsize=15)

# # Show legend
# plt.legend(fontsize=15)

# # Show plot
# plt.show()


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', which='major', pad=7, length=10,width=2)
ax.tick_params(axis='y', which='major', pad=7, length=10, width=2)
# ax.spines['top'].set_linewidth(1.85)
# ax.spines['right'].set_linewidth(1.85)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.set_ylim(0.45, 1.0)
ax.set_yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1.0])

plt.tight_layout()
plt.savefig('small_dataset_comparison.pdf',bbox_inches = "tight",transparent=True)
# Out:
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/357159057.py:29: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/357159057.py:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/357159057.py:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/357159057.py:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/357159057.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)

# %%
# Data
x = [0, 1, 2, 3, 4]
labels = ['Framingham (F)', 'MIMIC (F)', 'Heart (F)', 'Stroke (F)', 'Breast (F)']

# LR
y0 = [0.707, 0.612, 0.914, 0.848, 0.624]
y0err = [0.009, 0.011, 0.007, 0.017, 0.008]

# RF
y1 = [0.67, 0.836, 0.919, 0.786, 0.689]
y1err = [0.009, 0.001, 0.004, 0.012, 0.019]

# SVM
y2 = [0.615, 0.531, 0.918, 0.608, 0.664]
y2err = [0.008, 0.036, 0.004, 0.035, 0.016]

# SNN
y3 = [0.531, 0.909, 0.807, 0.546, 0.541]
y3err = [0.015, 0.002, 0.013, 0.044, 0.018]

# Ours
y4 = [0.705, 0.991, 0.923, 0.857, 0.694]
y4err = [0.008, 0.001, 0.004, 0.023, 0.017]

# Create a figure and a set of subplots
fig, ax = plt.subplots()

# Plot0
ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
ax.fill_between(x, y0 - np.array(y0err), y0 + np.array(y0err), alpha=0.2, facecolor='#DF9E9B',
                linewidth=0.1, antialiased=True)

# Plot1
ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
ax.fill_between(x, y1 - np.array(y1err), y1 + np.array(y1err), alpha=0.2, facecolor='#A8D3E3',
                linewidth=0.1, antialiased=True)

# Plot2
ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
ax.fill_between(x, y2 - np.array(y2err), y2 + np.array(y2err), alpha=0.2, facecolor='#ADD599',
                linewidth=0.1, antialiased=True)

# Plot3
ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
ax.fill_between(x, y3 - np.array(y3err), y3 + np.array(y3err), alpha=0.2, facecolor='#F6B37F',
                linewidth=0.1, antialiased=True)

# Plot4
ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
ax.fill_between(x, y4 - np.array(y4err), y4 + np.array(y4err), alpha=0.4, facecolor='#AB88BE',
                linewidth=0.1, antialiased=True)

# Set x-axis ticks and labels
ax.set_xticks(x)
ax.set_xticklabels(labels, rotation=30, fontsize=15)
ax.set_ylabel('AUC', fontsize=18)
plt.yticks(fontsize=15)


ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.tick_params(axis='x', which='major', pad=7, length=10,width=2)
ax.tick_params(axis='y', which='major', pad=7, length=10, width=2)
# ax.spines['top'].set_linewidth(1.85)
# ax.spines['right'].set_linewidth(1.85)
ax.spines['left'].set_linewidth(2)
ax.spines['bottom'].set_linewidth(2)
ax.set_ylim(0.45, 1.0)
ax.set_yticks([0.5, 0.6, 0.7, 0.8, 0.9, 1.0])

plt.tight_layout()
plt.savefig('full_dataset_comparison.pdf',bbox_inches = "tight",transparent=True)
# Out:
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/2205287181.py:29: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y0, '-k', color='#DF9E9B', label='Linear Regression')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/2205287181.py:34: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y1, '-k', color='#A8D3E3', label='Random Forest')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/2205287181.py:39: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y2, '-k', color='#ADD599', label='Support Vector Machine')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/2205287181.py:44: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y3, '-k', color='#F6B37F', label='Siamese Neural Network')
# /var/folders/yk/7ch8dmyd3zn7px5x485bylhdt8xk11/T/ipykernel_88684/2205287181.py:49: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "-k" (-> color='k'). The keyword argument will take precedence.
#   ax.plot(x, y4, '-k', color='#AB88BE', label='Ours', linewidth=3)
